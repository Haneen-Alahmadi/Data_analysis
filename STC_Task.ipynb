# %% [markdown]
# <a href="https://colab.research.google.com/github/Haneen-Alahmadi/Data_analysis/blob/main/STC_Task.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
# !pip install pyxlsb
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
import pandas as pd    
import pyxlsb

# %%
dataframe = pd.read_excel("/content/stc TV Data Set_T1.xlsb")

# %%
relationHD_programClass = dataframe.groupby(['program_class', 'program_genre']).agg(HD = ('hd', 'sum'))

# %%
relationHD_programClass
# Out:
#                                                       HD
# program_class   program_genre
# MOVIE           Action                             71448
#                 Adventure                              1
#                 Animation                         111550
#                 Biography                          11616
#                 Comedy                             39283
#                 Crime                               2281
#                 Documentary                         9398
#                 Drama                              38876
#                 Family                              3268
#                 Horror                             25062
#                 NOT_DEFINED_IN_UMS                  4491
#                 Sci-Fi                                 0
#                 Thriller                           14472
#                 Wrestling                              0
# SERIES/EPISODES Action                              4036
# ...

# %%
relationHD_programClass.sort_values(by=['HD'], inplace=True, ascending=False)

# %%
relationHD_programClass
# Out:
#                                                       HD
# program_class   program_genre
# MOVIE           Animation                         111550
#                 Action                             71448
#                 Comedy                             39283
#                 Drama                              38876
# SERIES/EPISODES Animation                          36701
# MOVIE           Horror                             25062
# SERIES/EPISODES Comedy                             21849
# MOVIE           Thriller                           14472
#                 Biography                          11616
#                 Documentary                         9398
# SERIES/EPISODES Drama                               8286
# MOVIE           NOT_DEFINED_IN_UMS                  4491
# SERIES/EPISODES Action                              4036
# MOVIE           Family                              3268
#                 Crime                               2281
# ...
